# %% [markdown]
# # tugas individu 1

# %%
from datetime import datetime

# %% [markdown]
# isi nama dan tgl lahir

# %%
nama = input("nama kamu: ")
tgl_lahir = input("tanggal lahir kamu (format: DD-MM-YYYY): ")
# Out:
# nama kamu: angga
# tanggal lahir kamu (format: DD-MM-YYYY): 21-10-2002

# %%
lahir = datetime.strptime(tanggal_lahir, "%d-%m-%Y")
sekarang = datetime.today()
umur = sekarang.year - lahir.year - ((sekarang.month, sekarang.day) < (lahir.month, lahir.day))
# Out:
# Halo angga, umur Anda 22 tahun.

# %% [markdown]
# output

# %%
print(f"Halo {nama}, umur Anda {umur} tahun.")
# Out:
# Halo angga, umur Anda 22 tahun.
